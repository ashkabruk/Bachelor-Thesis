# %%
import pandas as pd
import re
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
#!pip install unidecode
#!pip install datasketch
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import unidecode
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Dict
from collections import Counter
import random
from datasketch import MinHash, MinHashLSH
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
def measure_metrics(true_labels, predicted_labels):
    tp = 0
    tn = 0
    fp = 0
    fn = 0
    for i in range(len(true_labels)):
        golden = str(true_labels[i]).split(", ")
        predicted = str(predicted_labels[i]).split(", ")
        if len(golden) == 1 and len(predicted) == 1 and predicted == golden:
            tn += 1
        elif golden == predicted:
            tp += 1
        elif len(predicted) > len(golden):
            fp += 1
        else:
            fn += 1
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1score = 2*tp / (2*tp + fp + fn)
    return accuracy, precision, recall, f1score



def measure_metrics2(true_labels, predicted_labels, include_non_dups=False):
    pre = []
    rec = []
    f1 = []

    for i in range(len(true_labels)):
        tp = 0
        fp = 0
        fn = 0
        
        golden = str(true_labels[i]).split(", ")
        predicted = str(predicted_labels[i]).split(", ")
        
        # Check if there is an intersection before attempting to remove elements
        intersection = list(set(golden).intersection(set(predicted)))
        if intersection:
            to_remove = intersection[0]
            golden.remove(to_remove)
            predicted.remove(to_remove)
            
        if golden or predicted:
            for j in golden:
                if j in predicted:
                    tp += 1
                else:
                    fn += 1

            for j in predicted:
                if j not in golden:
                    fp += 1

            if tp + fp == 0:
                precision = 0
            else:
                precision = tp / (tp + fp)

            if tp + fn == 0:
                recall = 0
            else:
                recall = tp / (tp + fn)

            if precision + recall == 0:
                f1score = 0
            else:
                f1score = 2 * (precision * recall) / (precision + recall)
                
            pre.append(precision)
            rec.append(recall)
            f1.append(f1score)
            
        elif include_non_dups == True:
            pre.append(1)
            rec.append(1)
            f1.append(1)

    return np.mean(pre), np.mean(rec), np.mean(f1)


def replace_non_letters(input_string):
    return re.sub(r"[^a-zA-Z\s]", " ", input_string)

def unidecoded(panda_column):
    return panda_column.astype(str).apply(
        lambda x: unidecode.unidecode(
            x.replace("ä", "ae").replace("ö", "oe").replace("ü", "ue")
             .replace('Ä', 'Ae').replace('Ö', 'Oe').replace('Ü', 'Ue')))

true = [103]
predicted = [103]

measure_metrics2(true, predicted, include_non_dups=True)
# Out:
# (1.0, 1.0, 1.0)

# %%
def generate_emails(first_name, last_name):
    # Diese Funktion erzeugt eine Liste von E-Mail-Adressen basierend auf Vor- und Nachnamen
    # Diese Liste enthält verschiedene Formate wie Vorname.Nachname, VNach, Vorname usw.
    emails = []
    emails.append(f"{first_name.lower()}.{last_name.lower()}")
    emails.append(f"{first_name.lower()[0]}{last_name.lower()}")
    emails.append(f"{first_name.lower()}")
    emails.append(f"{first_name.lower()[0]}.{last_name.lower()}")
    emails.append("anderes")
    emails.append("info")
    emails.append(f"{last_name.lower()}")
    emails.append(f"{first_name.lower()}{last_name.lower()}")
    emails.append(f"{first_name.lower()}.{last_name.lower()}1990")  # Vor.NachnameJahr
    return emails

def fake_emails(first_name, last_name):
    # Diese Funktion generiert eine E-Mail-Adresse basierend auf den gegebenen Wahrscheinlichkeiten
    distr = {
        "vor.nach": 55/100,
        "vnach": 10/100,
        "vor": 9/100,
        "v.nach": 6/100,
        "anderes": 6/100,
        "info": 5/100,
        "nach": 4/100,
        "vornach": 3/100,
        "vor.nachjahr": 2/100
    }
    
    # Generiere eine Liste von E-Mail-Adressen
    emails = generate_emails(first_name, last_name)
    
    # Wähle zufällig eine E-Mail-Adresse basierend auf den Wahrscheinlichkeiten aus
    random_percentage = random.random()
    total = 0
    i = 0
    for scenario, percentage in distr.items():
        total += percentage
        if random_percentage <= total:

            return emails[i]  # Gib die E-Mail-Adresse zurück
        else:
            i += 1

def plausible_email(first_name, last_name, email):
    email = email.split("@")[0]
    email = re.sub(r'\d+', '', email)
    plausible_formats = [
        f"{first_name.lower()}.{last_name.lower()}",
        f"{first_name.lower()}{last_name.lower()}",
        f"{first_name.lower()[0]}{last_name.lower()}",
        f"{first_name.lower()}",
        f"{first_name.lower()[0]}.{last_name.lower()}",
        f"{last_name.lower()}",
    ]
    
    if first_name and last_name in email:
        return True
    else:
        return email in plausible_formats

# Beispielvor- und nachname
first_name = "Max"
last_name = "Mustermann"

df = pd.read_excel("Testcases.xlsx")

for vor, nach, email in zip(unidecoded(df["Vorname"]).to_list(), unidecoded(df["Nachname"]).to_list(), unidecoded(df["Email"]).to_list()):
    res = plausible_email(vor, nach, email)
    print(res)
    # Generiere eine E-Mail-Adresse basierend auf den Wahrscheinlichkeiten
    #generated_email = fake_emails(unidecode(str(vor)), unidecode(str(nach)))

    # Ausgabe der generierten E-Mail-Adresse
    #print(generated_email)
# Out:
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# False
# True
# False
# True
# False
# True
# False
# False
# False
# True
# False
# True
# False
# True
# False
# False
# True
# True
# True
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# False
# True
# True
# True
# True
# False
# False
# False
# True
# True
# False
# False
# True
# False
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# False
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True

# %%
df = pd.read_excel("Testcases.xlsx")

#replace Umlaute
df["Vorname"] = df['Vorname'].str.replace('ä', 'ae').str.replace('ö', 'oe').str.replace('ü', 'ue').str.replace('Ä', 'Ae').str.replace('Ö', 'Oe').str.replace('Ü', 'Ue')
df["Nachname"] = df['Nachname'].str.replace('ä', 'ae').str.replace('ö', 'oe').str.replace('ü', 'ue').str.replace('Ä', 'Ae').str.replace('Ö', 'Oe').str.replace('Ü', 'Ue')

def simple(full_name):
    namen = {}

    for index, name in full_name.items():
        if name == "":
            continue

        if name in namen:
            namen[name].append(int(df.at[index, "ID"]))
        else:
            namen[name] = [int(df.at[index, "ID"])]

    df["Simple Match"] = str(0)
    for n in namen:
        for m in namen[n]:
            df.at[m-1, "Simple Match"] = str(namen[n])[1:-1]


    sorted_dict = dict(sorted(namen.items(), key=lambda item: item[1], reverse=True))

# %%
import unidecode
import pandas as pd

def soundex(full_name):
    soundex_mapping = {
        "a": "0", "e": "0", "i": "0", "o": "0", "u": "0", "ä": "0", "ö": "0", "ü": "0", "y": "0", "j": "0", "h": "0",
        "b": "1", "p": "1", "f": "1", "v": "1", "w": "1",
        "c": "2", "s": "2", "k": "2", "g": "2", "q": "2", "x": "2", "z": "2", "ß": "2",
        "d": "3", "t": "3",
        "l": "4",
        "m": "5", "n": "5",
        "r": "6",
        "ch": "7", "sch": "7", "sh": "7",
        "-": " "
    }

    soundex_codes = {}

    for index, name in full_name.items():
        if name == "":
            continue

        name = name.lower()
        name = name.replace("sch", "7").replace("ch", "7").replace("sh", "7")

        soundex_code = name[0].upper()

        previous_digit = ""
        for letter in name[1:]:
            if letter in soundex_mapping:
                current_digit = soundex_mapping[letter]
                if current_digit != previous_digit and current_digit != "0":
                    soundex_code += current_digit
                    previous_digit = current_digit

        soundex_code = soundex_code[:4]

        while len(soundex_code) < 4:
            soundex_code += '0' 
        if soundex_code in soundex_codes:
            soundex_codes[soundex_code].append(index+1)
        else:
            soundex_codes[soundex_code] = [index+1]
            
    df["Soundex"] = str(0)
    
    for n in soundex_codes:
        for m in soundex_codes[n]:
            df.at[m-1, "Soundex"] = str(soundex_codes[n])[1:-1]

# %%
#Soundex representation
df = pd.read_excel("Testcases.xlsx")

def soundex_custom(full_name):
    soundex_mapping = {
            "a": "0", "e": "0", "i": "0", "o": "0", "u": "0", "ä": "0", "ö": "0", "ü": "0", "y": "0", "j": "0", "h": "0",
            "b": "1", "p": "1", "f": "1", "v": "1", "w": "1",
            "c": "2", "s": "2", "k": "2", "g": "2", "q": "2", "x": "2", "z": "2", "ß": "2",
            "d": "3", "t": "3",
            "l": "4",
            "m": "5", "n": "5",
            "r": "6",
            "ch": "7", "sch": "7",
            "-": " "
        }

    soundex_namen = {}

    for index, name in full_name.items():

        if name == "" or pd.isna(name):
            continue

        name = str(name).replace("sch", "7").replace("ch", "7").replace("sh", "7")

        soundex_name = ""
        soundex_name += name[0]

        for letter in name.lower()[1:]:
            if letter in soundex_mapping and soundex_mapping[letter] != soundex_name[-1]:
                soundex_name += soundex_mapping[letter]

            elif letter not in soundex_mapping:
                soundex_name += letter
                
        if soundex_name in soundex_namen:
            soundex_namen[soundex_name].append(int(df.at[index, "ID"]))
        else:
            soundex_namen[soundex_name] = [int(df.at[index, "ID"])]

    df["Soundex Custom"] = str(0)
    for n in soundex_namen:
        for m in soundex_namen[n]:
            df.at[m-1, "Soundex Custom"] = str(soundex_namen[n])[1:-1]

# %%
def levenshteinDistance(A, B):
    N, M = len(A), len(B)
    
    dp = [[0 for i in range(M + 1)] for j in range(N + 1)]

    for j in range(M + 1):
        dp[0][j] = j
        
    for i in range(N + 1):
        dp[i][0] = i
        
    for i in range(1, N + 1):
        for j in range(1, M + 1):
            if A[i - 1] == B[j - 1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = 1 + min(
                    dp[i-1][j],
                    dp[i][j-1],
                    dp[i-1][j-1]
                )

    return dp[N][M]

# %%
#replace Umlaute

df["Vorname"] = df['Vorname'].str.replace('ä', 'ae').str.replace('ö', 'oe').str.replace('ü', 'ue').str.replace('Ä', 'Ae').str.replace('Ö', 'Oe').str.replace('Ü', 'Ue')
df["Nachname"] = df['Nachname'].str.replace('ä', 'ae').str.replace('ö', 'oe').str.replace('ü', 'ue').str.replace('Ä', 'Ae').str.replace('Ö', 'Oe').str.replace('Ü', 'Ue')


def levenshtein(full_name, max_distance=3):
    namen = {}
    max_distance = 3

    for index, name in full_name.items():
        if pd.isna(name):
            continue
        if name not in namen:
            namen[name] = [int(df.at[index, "ID"])]
        elif pd.notna(df.at[index, "ID"]):
            namen[name].append(int(df.at[index, "ID"]))

    for name in namen:
        for n in namen:
            if any(namen[n]) not in namen[name]:
                if levenshteinDistance(name, n) in range(1, max_distance):
                    namen[name] += namen[n]
                    namen[name] = list(set(namen[name]))


    df["Levenshtein"] = str(0)
    for n in namen:
        for m in namen[n]:
            df.at[m-1, "Levenshtein"] = str(namen[n])[1:-1]

# %%
def koln(df, column_name):
    koln_mapping = {
        "a": "", "e": "", "i": "", "o": "", "u": "", "ä": "", "ö": "", "ü": "", "y": "", "j": "", "h": "",
        "b": "1",
        "f": "3", "v": "3", "w": "3",
        "g": "4", "k": "4", "q": "4",
        "l": "5",
        "m": "6", "n": "6",
        "r": "7",
        "s": "8", "z": "8",
        "-": ""
    }

    def koln_encode(name):
        if name != "":

            koln_name = [str(name)[0]]

            for n, letter in enumerate(str(name)[1:], start=1):
                if letter == "p":
                    if n < len(name) and name[n] == "h":
                        koln_name.append("3")
                    else:
                        koln_name.append("1")

                elif letter in "dt":
                    if n < len(name) and name[n] in "csz":
                        koln_name.append("8")
                    else:
                        koln_name.append("2")

                elif letter == "c":
                    if n == 1 and n < len(name) and name[n] in "ahkloqrux":
                        koln_name.append("4")
                    elif n < len(name) and name[n] in "ahkloqrux" and name[n - 1] not in "sz":
                        koln_name.append("4")
                    else:
                        koln_name.append("8")

                elif letter == "x":
                    if name[n - 1] in "ckq":
                        koln_name.append("8")
                    else:
                        koln_name.append("48")

                elif letter in koln_mapping and (not koln_name or koln_mapping[letter] != koln_name[-1]):
                    koln_name.append(koln_mapping[letter])

            koln_name = ''.join(koln_name[i] for i in range(len(koln_name)) if i == 0 or koln_name[i] != koln_name[i-1])
            return koln_name
        

    df["Koln"] = df[column_name].apply(koln_encode)

    koln_namen = df.groupby("Koln")["ID"].apply(list).to_dict()

    df["Koln"] = df["Koln"].map(lambda k: ", ".join(map(str, koln_namen.get(k, []))) or "0")

# %%
def ngrams(text, n=2):
    text = f"{'#' * (n-1)}{text.lower().replace(' ', '_')}{'#' * (n-1)}"
    return [text[i:i+n] for i in range(len(text) - n + 1)]

def cosine_similarity(ngrams1, ngrams2):
    freq_vector1 = Counter(ngrams1)
    freq_vector2 = Counter(ngrams2)

    unique_ngrams = set(freq_vector1.keys()) | set(freq_vector2.keys())

    dot_product = sum(freq_vector1[ngram] * freq_vector2[ngram] for ngram in unique_ngrams)

    magnitude1 = np.sqrt(sum(freq_vector1[ngram] ** 2 for ngram in unique_ngrams))
    magnitude2 = np.sqrt(sum(freq_vector2[ngram] ** 2 for ngram in unique_ngrams))

    similarity = dot_product / (magnitude1 * magnitude2)

    return similarity


def ngram_similarity(full_name, ngram=3, border=0.65):
    df["Ngram Similarity"] = str(0)
    similarities = {}
    names = full_name.to_list()

    for i in range(len(names)):
        for j in range(i + 1, len(names)):
            ngrams1 = ngrams(names[i], ngram)
            ngrams2 = ngrams(names[j], ngram)
            if cosine_similarity(ngrams1, ngrams2) > border:
                if i not in similarities:
                    similarities[i] = [i+1, j+1]
                else:
                    similarities[i].append(j+1)
                
                print(cosine_similarity(ngrams1, ngrams2), names[i], names[j])

        if i not in similarities:
            similarities[i] = [i+1]

    for i in similarities:
        for j in similarities[i]:
            if df.at[j-1, "Ngram Similarity"] == str(0):
                df.at[j-1, "Ngram Similarity"] = str(similarities[i])[1:-1]

# %%
def minhash_for_ngrams(ngrams, num_perm=128):
    mhash = MinHash(num_perm=num_perm)
    for ngram in ngrams:
        mhash.update(ngram.encode("utf-8"))
    return mhash

def lsh_similarity_check(full_name, ngram_size=2, threshold=0.65, num_perm=128):
    lsh = MinHashLSH(threshold=threshold, num_perm=num_perm)
    minhashes = {}
    similarities = []

    for index, name in full_name.items():
        if name == "":
            continue
        name_ngrams = ngrams(str(name), ngram_size)
        mhash = minhash_for_ngrams(name_ngrams, num_perm)
        lsh.insert(f"name{index}", mhash)
        minhashes[f"name{index}"] = mhash

    df["LSH Similarity"] = pd.Series([set() for _ in range(len(df))])

    for key, minhash in minhashes.items():
        potential_matches = lsh.query(minhash)
        index_key = int(key.replace("name", ""))
        for match in potential_matches:
            if key != match:
                index_match = int(match.replace("name", ""))
                actual_similarity = minhash.jaccard(minhashes[match])
                if actual_similarity >= threshold:
                    similarities.append(actual_similarity)
                    df.at[index_key, "LSH Similarity"].add(index_match+1)
                    df.at[index_match, "LSH Similarity"].add(index_key+1)
            elif key == match:
                df.at[index_key, "LSH Similarity"].add(index_key+1)
                
                
    df["LSH Similarity"] = df["LSH Similarity"].apply(lambda x: str(sorted(list(x)))[1:-1] or "0")


def jaccard_similarity(list1, list2):
    set1 = set(list1)
    set2 = set(list2)
    
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    
    if len(union) == 0:
        return 1.0
    jaccard_index = len(intersection) / len(union)
    
    return jaccard_index

print(jaccard_similarity("Henri Waternoose", "Henry Peter Waternose"))
print(cosine_similarity(ngrams("johann johann", 3), ngrams("johann seeler", 3)))


print(jaccard_similarity(ngrams("robert frei", 2), ngrams("robert frei robert", 2)))
print(jaccard_similarity(ngrams("Henri Waternoose", 2), ngrams("Henry Peter Waternose", 2)))
print(cosine_similarity(ngrams("Henri Waternoose", 3), ngrams("Henry Peter Waternose", 3)))

print(jaccard_similarity(ngrams("mario mueller", 3), ngrams("maria mueller", 3)))
print(jaccard_similarity(ngrams("juergen kaiser", 3), ngrams("juergen geiser", 3)))
# Out:
# 0.7692307692307693
# 0.5922200922639821
# 0.7333333333333333
# 0.6086956521739131
# 0.6599663291074445
# 0.6666666666666666
# 0.6

# %%
"""
Rerun all algorithms, if "TypeError: 'tuple' object is not callable" appears

"""

df = pd.read_excel("Testcases.xlsx")
import time

vornamen = unidecoded(df["Vorname"]).to_list()
nachnamen = unidecoded(df["Nachname"]).to_list()
emails = unidecoded(df["Email"]).to_list()


df["Standardized"] = str(0)
index = 0
for vor, nach, email in zip(vornamen, nachnamen, emails):
    full_name = replace_non_letters(f"{vor} {nach}".lower())
    email_prefix = email.split("@")[0].lower()
    email_prefix = replace_non_letters(re.sub(r'\d+', '', email_prefix))
    
    if vor == "nan" or nach == "nan":
        if email != "nan":
            to_check = email.split(".")[0]
                                                               
        else:
            to_check = ""
            
    elif plausible_email(vor, nach, email):
        to_check = full_name
    
    elif cosine_similarity(ngrams(full_name, 2), ngrams(email_prefix, 2)) > 0.65:
        to_check = email_prefix
        print(to_check, "|", full_name)
    
    else:
        to_check = full_name
    df.at[index, "Standardized"] = to_check
    index += 1
    
simple(df["Standardized"])
soundex(df["Standardized"])
soundex_custom(df["Standardized"])
koln(df, "Standardized")
levenshtein(df["Standardized"])
ngram_similarity(df["Standardized"], 3)
start = time.time()
lsh_similarity_check(df["Standardized"], 2)
end = time.time()

print(end - start)
df.to_excel("output.xlsx")
# Out:
# marko dobec | marko marko dobec
# elion metaj | elion metaj
# simko daniel | daniel simko
# jean claude gerber | jean claude gerber
# daniel huber | daniel p  huber
# bianchi simon | simon bianchi
# selina studer | selina studer
# peter mueller | peter ch  mueller
# emilie neukom | emilie emilie neukom
# christoph aebi | christoph aaebi
# luzi tiefenauer | luzi tiefenauer
# stefan rudolf | stefan f  rudolf
# michaelbooz ch | michael booz
# sven tiemann | sven h  tiemann
# michael ullrich | michael michael ullrich
# richard hatuev | richard richard hatuev
# weidlich matthias | matthias weidlich
# thomas d meyer | thomas d  meyer
# thomas a friedrich | thomas friedrich
# d gnaegi bernstein | daniela gnaegi bernstein
# chris krammer | chris kramer
# niestroj paul | paul niestroj
# tobias schmidt | tobias schmidt
# gregor naef | gregor r  naef
# bmhaemmerli | bernhard m  haemmerli
# reto luginbuehl | reto luginbuehl
# dominique studer | studer dominique
# adrian weiss | adrian weiss
# ch angehrn | christa angehrn
# jasmine birkle | jasmine birkle
# frederic furrer | furrer frederic
# rebeccamirjammeier | rebecca meier
# jan buetiger | jan bueetiger
# nebojsa andelkovic | nebojsa andjelkovic
# alain deveer | alain de veer
# gianni diiorio | gianni di iorio
# milenko kovacevic | milenko kovacevic
# maira moosmann | maira moosmann
# christian naef | christian naef
# mario siano | mario siano
# samuel truessel | samuel truessel
# miro zlatkovic | miroljub zlatkovic
# max vonburg | max von burg
# julliana zuellig | zuellig julliana
# aysun oenaktug | aysun oenaktug kissling
# carlo canova | carlo canova
# martin meyer | martin meyer jutzi
# monique leeser | monique leeser
# hanspeter nehmer | hans peter nehmer
# janine christina bettschart | janine bettschart
# zuber petra | petra zuber
# sanjaa uzevskaa | uzhevska sanja
# thomas schilling | tom schilling
# tom lack | thomas lack
# robegli | robert robert egli
# varunfre | varun frei
# eric vonah | eric von ah
# hanspeter keller | hanspeter keller
# etienne vonthiessenf | raphael etienne von thiessen
# isabel vanalphen | isabel van alphen
# urs schmid | urs urs schmid
# robert knop | robert knop
# irene eigenmann | irene eigenmann timmings
# markus bruetting | markus bruetting
# daniela tobler | daniela tobler koenen
# philip schoenholzer | philip philip schoenholzer
# hanspeter wolf | hans peter wolf
# gharenberg | brenda harenberg
# angelica bienz | angelica angelica bienz
# michele schulthess | michele buecheler
# tanja santner steinebrunner | tanja christina santner steinebrunner
# george meier | georg georg meier
# martin keller  | martin keller
# lin bertschijadama | lin bertschi jadama
# mark naef | markus naef
# bettina bertschijadama | bettina bertschi jadama
# ramon comi | ramon comi
# martin m lienhard | martin lienhard
# peter raess | peter raess
# carmen delacruz | carmen de la cruz
# andre vonarb | andre von arb
# nichoas long | nick long
# toni caradonna | toni caradonna
# marco fruh | marco frueh
# raffael schuppisser | raffael schppisser
# sandro vonins | sandro von ins
# caspar vonstuelpnagel | caspar v  stuelpnagel
# david merton | david mertin
# anja benisch | anja anja benisch
# corina wherry obrist | corina corina wherry obrist
# corinna froeschke | corinna corinna froeschke
# michiel hamberg | michel hamberg
# beat knechtli | beat knechtli
# laurens debever | laurens laurens de bever
# lydia welzel | lydia lydia welzel
# markus land | markus markus land
# ursula maurer | ursula maurer
# noemi schneider | noemi noemi schneider
# maurus thurneysen | maurus thurneysen
# filip van herle | filip van herle
# yannick huerbin | yannick yannick huerbin
# martin pauli | martin martin pauli burckhardt
# luana staempfli | luana luana staempfli
# rainer richter | rainer m  richter
# geert vaneijnatten | geert van eijnatten
# patrick geiser | patrick geiser
# rolf bollman | rolf bollmann
# raphael kunderer | raphael raphael kunderer
# klinkert cedric | cedric klinkert
# jasminettlin | jasmini ettlin
# jasettlin | jasmin jasmin ettlin
# shpend kelmendi | shpend kelmendi
# patrick labud | partrick labud
# krivonog neza | neza krivonog
# tomas chroust | tomas tomas chroust
# adrian vonkaemel | adrian von kaenel
# pablo fernandezmacho | pablo fernandez macho
# monorumphilippe phy | philippe phy
# markus vonallmen | markus von allmen
# peter burkhalter | peter peter burkhalter
# rouven mayer | rouven mayer
# s rappoconca | sabine rappo conca
# anita schuler | anita anita schuler
# olga rosa | olga rosa
# joe kurmann | joe a  kurmann
# hans joerg villiger | hans joerg villiger
# benjamin moeller | benjamin moeller
# renato comelli | renato comelli
# drazen berblich | drazen johannes berblich
# hans werner feick | hans werner feick
# angela spaeth | angela spaeth
# leoertle | levin oertle
# andreas bauer | andreas bauer
# alexander pointer | alexander pointer
# andrea schula | andrea schula
# marco trachsel | marco trachsel
# erich birchler | erich linus birchler
# lothar baumgartner | lothar f baumgartner
# helena mader | helena helena mader
# m wolfensberger | dr  michael wolfensberger
# ulrike albath | ulrike  albath
# st menzl | stefan menzl
# lisa parmentier | lisa lisa parmentier
# christoph odermatt | chris odermatt
# e degrandi | emanuele de grandi
# kurt christen | christen kurt
# roland a kunz | roland kunz
# sabrina de vries | sabrina de vries
# markus vonallmen | markus von allmen
# barbara kueng | babrbara kueng
# charlotte sgier | charlotte sgier de cerf
# marie france cochard | marie france cochard
# patrick belser | belser patrick
# n vonostheim | norbert von ost heim
# mc federspiel | marie claude federspiel
# marusa kupper | marusa grobelnik kupper
# giuseppe dangeli | giuseppe d angeli
# heinz achermann | heinz j  achermann
# katja alder | katja katja alder
# cannekathrin kruegel falkenberg | annekathrin kruegel falkenberg
# roland luethi | roland luethi oetterli
# tabea krebs | tabea krebs
# susanne stauber | susanne susanne stauber
# greg hernan | gregoire hernan
# jensj  wolf | jens wolf
# iris mathez | iris iris diana mathez
# ch langenberger | christiane langenberger
# jose antonio alvarez | jose alvarez
# nicolas miescher | nicolas mischer
# class bollen | claas bollen
# rolf rh huber | rolf huber
# ivo malnati | ivo melnati
# stefan neuenschwnder | stefan neuenschwander
# toni larosa | toni la  rosa
# bijan ghasemi | bijan ghasemi
# jose gomez | jose gomez
# helga schlumpf | helga helga schlumpf
# njomza nuza | njomza njomza nuza
# mario porchet | mario porchet
# stefan kuttel | stefan kuettel
# gerhard schuermann | gerhard schuerrmann
# monika bigler | monika bigler waelti
# monique abgottspon | monique monique abgottspon
# monika vogt hammel | monika vogt hammel
# tanja maeder | tanja maeder
# nicolas keller | nicolas nicolas keller
# schumacher marcel | marcel schumacher
# michela donofrio | michela d onofrio
# rolf bueler | rolf bueeler
# daniel waelchli | waelchli daniel
# lorena serratore | lorena serratore
# michael brasse | michael brasse
# pascal roth | pascal roth
# nora suranyi | nora suranyi
# fred tanner | fred tanner
# angela larger | angela larger lauricella
# massimo bernasconi | m  bernasconi
# sanne stijve | sanne stijve
# jeanpaul tschumi | jean paul tschumi
# visser wicher | wicher visser
# ggabriela schleuniger | gabriela schleuniger
# fredi ziegler | alfred ziegler
# klaus dieterich maier | klaus d  maier
# besma hamdi | hamdi besma
# andreas kaden | andreas andreas kaden
# lino guzzella | lino guzella
# karin kelly | kelly karin
# katrin reschwamm | katrin katrin reschwamm
# matthias hoffmann | matthias hoffmann
# theodor biedermann | theo biedermann
# zoltan j szekelyfoeldi | zoltan szekelyfoldi
# nicole kuster | nicole  kuster
# susanne schmidt | susanne susanne schmidt rauch
# r tanner | p  tanner
# stephanschlegel | stephan schlegel
# franziska steidle | franziska steidle sailer
# marina elef | marina marina eleftheriadou
# simon rickenbacher | simon rickenbach
# oliver fuchs | oliver oliver fuchs
# luzia hafen | luzia stefanie hafen
# roger stuessi | roger stuessi gamma
# horst dieter froede | horst froede
# andreas wagner aw | andreas wagner
# menandreas janka | men andreas janka
# galia kondova | galia kondova
# marc peter | dr  marc k  peter
# samuel zaech | samuel samuel zaech
# stella gatziugrivas | stella gatziu grivas
# fred vandenanker | fred van den anker
# thomas rieder | rieder thomas
# sarariccardo | sara riccardo
# cecile bachmann | cecile cecile bachmann
# oliver ittig | oliver oliver ittig
# michael benjamin | benjamin michael
# katrin huegel | katriin huegel
# julia hotz | julia hotz messerli
# adrian ensner | adrian ensner
# natascha desmarais | natascha desmarais
# christof heiss | christof heiss
# pascal vangelderen | pascal van gelderen
# alwin seiverth | alwin alwin seiverth
# becker astrid | astrid becker
# marco brack | marco brack
# daniel santos | daniel daniel santos
# lukas meier | meier lukas
# flo amstutz | florian amstutz
# kfurrer | kurt furrer
# michiastegegne | michias tegegne
# christian franck | christian  franck
# tiz nessi | tiziano nessi
# stefan mattenberger | stefan stefan mattenberger
# mirjam leu | mirjam leu theiler
# philipp riniker | philipp georg riniker
# karl gutbrod | karl g  gutbrod
# philippe steiner | phillipp steiner
# claude finance | clauce finance
# schmideric | eric schmid
# christine steiger | christine stieger
# christian vonallmen | christian von allmen
# rene raeber | rene rene raeber
# reto aeberhard | aeberhard reto
# maria kreimer | maria maria kreimer
# pascale orlow | pascale orlow
# yanira gonzalez | yanira gonzales
# patrick moser | patrick mosberger
# philipp uhllmann | philipp uhlmann
# christian scherer | christian christian scherer
# luca dacosta | luca da costa
# agnes herfurth | aga herfurth
# irene bellora | bellora irene
# stefan j barac | stefan barac
# lorenz soluthurnmann | lorenz soluthurnmann
# gabriele vonplanta | gabriele von planta
# arjan decarpentier | arjan de carpentier
# pasqual vossberg | pasqual vossberg
# andrea zimmermann | andrea zimmermann murer
# michele | michele matt
# stefan maurer | stefan stefan maurer
# marc dikotter | marc dikoetter
# anki dubach | andrea dubach
# martin pulver | martin pulfer
# dominik riether | dominik riether
# marc pittner | marc pittner
# claudia friedli | claudia friedl
# markus vongruenigen | markus von gruenigen
# ghislaine lamanthe | ghisaine lamanthe
# klaus buckalassen | klaus bucka lassen
# michael gassmann | gassmann michael
# michel meyer | c o michel michel meyer
# hansruedi vondermuehll | hansruedi vonder muehll
# lea lutz | lea lutz knobel
# mischa haechler | mischa nicolas haechler
# jole orizet | joel orizet
# susann klossek | ssann klossek
# romana kaspar | romana kasper
# petro kocherhan | petro kocherhan
# brian r | brian ruchti
# nikokarner | nikolas karner
# stephane blanc ch | stephane blanc
# ramona engel | ramona engel paintner
# denis druzic | denis druzic
# christoph siegrist | christoph christoph siegrist
# eohninger | ernst oehninger
# bea golob | beatrice golob
# peer dietrich | dietrich peer
# robert houska | robert houska
# martin d kunz | martin kunz
# billy kenubuehl | billy kneubuehl
# caterina van leeuwen | caterina van leeuwen
# manuel brandli | manuel braendli
# johannes dumitru | johannes dumitru
# nima lari | nima dominik lari
# roswitha levy | roswitha ostermann levy
# slawomir kleeb | slawomir kleeb
# gabrielle vonarx | gabrielle von arx
# danilo demilio | danilo d emilio
# michael gutknechct | michael gutknecht
# kai eberhardt | kai eberhard
# minli marti | min li marti
# jalil hashemi | jalil jalil hashemi
# malgorzata galeska | galeska malgorzata
# stefan kueffer | stefan stefan kueffer
# joerg koch | joerg  koch
# christophe beaud | chrisophe beaud
# adi baertschi | adrian baertschi
# markus bruetting | markus bruetting
# sven blumenstiel | sven blumenstiel
# philippe schmidig | philippe philippe schmidig
# cristopher alcaide | cristopher alcaide amrein
# desiree depra | desiree de pra
# zita rovo | zita zita rovo
# dieter huber | dieter huber
# mijovanovic | milan jovanovic
# fahimeh karbalaei | fahimeh fahimeh karbalaei
# adrian gerzner | adrian gernzner
# svschieffer | stella schieffer
# michel patteet | michael patteet
# marc schmid  | marc schmid
# martin wenger  | martin wenger
# peter k maeder | peter maeder
# michael schwab  | michael schwab
# matthias vonwartburg | matthias von wartburg
# daniel nyffenegger  | dani nyffenegger
# andreaalessandro stern | andrea stern
# nicole stucki | nicole b  stucki
# peter waelti  | peter waelti
# inga vangessel | inga van gessel
# oliver deboni | oliver de boni
# thomas sutter | sutter thomas
# jeffreydavid iqbal | jeffrey iqbal
# matthias bryner | matthias matthias bryner
# brigitte hoelzb | brigitte hoelz
# jonas greminger | jonas greminger
# matthias herrmann | matthias herrmann
# mburkart | marcel burkart
# kevin hansen | kevin hansen
# mr lehmann | marc roman lehmann
# roland voneuw | roland von euw
# thomaspaulus | thomas thomas paulus
# anna rosenloehner | anna rosenloehner
# celine kopf | celine kopf
# patrick grzinic | patrick grzinic
# reto demartin | reto de martin
# coberholzer | cornelia oberholzer nyman
# alexandra krauer | alexandra alexandra krauer
# cmichailidou | tina michailidou
# penny schiffer | penny schiffer
# katharina vogt | katharina vogt schaedler
# juerg vogelsang | juerg vogelsang
# heinz toebben | heinz toebben
# anton miric | anton z  miric
# sasa grzinic | sasa gabriel grzinic
# vondach daniel | daniel von dach
# beat vonkaenel | beat von kaenel
# david vaselle | david vasella
# martin gajdos | martin martin gajdos
# kim bolleter | kim jessica bolleter
# dario camirro | dario cimirro
# stephanie kuenzli | stephanie kuenzli
# daniel joost | daniel daniel joost
# christina thoma | christina christina thoma
# gianni petrone | gianni petrone
# deborah luetolf | deborah luetolf   van zee
# sonja cucuz | sonja sonja cucuz
# ulrike pertoll | ulrike pertoll
# suzana langenegger | suzana langenegger
# nina kessler | nina kessler
# marc fischer | marc fischer
# beatrice vonarx | beatrice von arx
# marcel wiesendanger | marcel wiesendanger
# kai vonmassenbach | kai von massenbach
# christian russ | christian russ
# christof hoefner | christof christof hoefner
# claudio zenerino | claudio claudio zenerino
# anna engeler | anna anna engeler
# daniel grundelsweiler | fredrik grundelsweiler
# carmen wehnelt | carmen wehnelt
# monika rohrer | monika rohrer
# chris russ | christian russ
# reto schnellmann | reto  schnellmann
# franz roeoesli | franz roesli
# alessandro de pin | alessandro de pin
# claudia stadler | claudia stadler
# michele di biase | michele di biase
# rosmarie friedli | rosmarie friedli wilson
# philipp grossmann | phiipp grossmann
# jonas hedinger | jonas hediger
# joseph linssen | joseph linssen
# thomas goepfert | thomas thomas goepfert
# jeffrey van baar | jeffrey van baar
# werner scherrer | werner  scherrer
# eva schauer | eva m  schauer
# nalini karunanidhi willi | nalini willi
# philipp ebneter ict | philipp ebneter
# franz erni | franz erni
# erni peter | peter erni
# peter frei kaliga | peter frei
# roland frobel | roland froebel
# silvia heinz privat | silvia heinz
# anne hensen | annedore hensen
# margret kiener | margret kiener nellen
# remo kleiner | remo kleiner
# konikreis | konrad kreis
# cyrill meier | cyrill meier
# patrick p pfister | patrick pfister
# stefan portmann | stefan portmann
# roger schmid  | roger schmid
# chregischneider | christian schneider
# philippe schneider | philippe schneider
# thomas schroff | thomas schroff
# steiner thierry | thierry steiner
# stocker patrick | patrick stocker
# tobler rolf | rolf tobler
# ueli wiederkehr | ueli wiederkehr
# lennartcwitt | lennart witt
# chrigu zahnd | christian zahnd
# jac braun | jacques braun
# andreas buehler | andreas buehler
# matbuetler | matthias buetler
# andreas buzzi | andreas buzzi
# matti staufer | matthias staufer
# cesia amareli | cesla amarelle
# kathrin berschy | kathrin bertschy
# pascale bruderer | pascale bruderer wyss
# roland buechel | roland rino buechel
# miachel buffat | michael buffat
# christine buillard marbach | christine bulliard marbach
# yannick buffet | yannick buttet
# martin cardinas | martin candinas
# marino carobbio | marina carobbio guscetti
# dominique debuman | dominique de buman
# thomas decourten | thomas de courten
# laurence fehlmann rielle | laurence fehlmann rielle
# sylvia flueckiger | sylvia flueckiger baehni
# andrea geissbuehler | andrea martina geissbuehler
# ida glanzmann | ida glanzmann hunkeler
# alice glauser | alice glauser zufferey
# andrea gmuer | andrea gmuer schoenenberger
# berhard guhl | bernhard guhl
# ruth humbel | ruth humbel naef
# karin keller suter | karin keller sutter
# geraldine merchand balet | geraldine marchand balet
# liliane maurypasquier | liliane maury pasquier
# tiana moser | tiana angelina moser
# roger normann | roger nordmann
# verlie piller carrard | valerie piller carrard
# rebeccaana ruiz | rebecca ana ruiz
# elisabeth schneider | elisabeth schneider schneiter
# jean christophe schwaab | jean christophe schwaab
# priska seiler | priska seiler graf
# anne seydoux | anne seydoux christe
# marianne streiff | marianne streiff feller
# albert viatli | albert vitali
# erich vonsiebenthal | erich von siebenthal
# david zueberbuehler | david zuberbuehler
# jonathanabplanalp | jonathan abplanalp
# amarilys a | amarilys abreu
# evebuya | evelyne abuya
# achermann thomas | thomas achermann
# adamo rossi | rossi adamo
# bes ademi | besnik ademi
# affentrangerp | peter affentranger
# stefan agresta | stefan agresta
# alex aguilar | alejandro aguilar
# dario albanesi | dario albanesi
# jualcivar | juan alcivar
# alder stefan | stefan alder
# alen piljic | alen alen piljic
# lena altendorfer | elena altendorfer
# amandine revol | amandine amandine revol
# phammann | philipp ammann
# corinne amrein | corinne amrein
# st amrhein | stefan amrhein
# anandrohit | rohit anand
# br anceschi | bruno anceschi
# dani andermatt | daniel andermatt
# andrea bozzi | bozzi andrea
# andreas schwarz | andreas andreas schwarz
# voigt andreas | andreas andreas voigt
# charline andrees intern | charline andrees
# tobias angehrn | tobias angehrn
# angelica duenner | angelica angelica duenner
# annatina fuenfschilling | annatina annatina fuenfschilling sigg
# estefan antelo | estefan antelo doval
# sidarora | siddhartha arora
# tobiartho | tobias artho
# petra asprion | petra maria asprion
# domi auer | dominik auer
# raphael aufdermaur | raphael auf der maur
# johann aumann | johannes aumann
# ozgur aytekin | oezguer aytekin
# babik christoph | christoph babik
# babirajh kandiah | babirajh babirajh kandiah
# bachmann andrea  | andrea bachmann
# lilienbeatrice bachmann | lilien beatrice bachmann
# c w bachmeier | werner bachmeier
# th bader | thomas bader
# viviane bader | viviane bader
# ball alexander | alexander ball
# roger ballmer | roger ballmer
# chrbalmer | christian balmer
# bamerbalazs | balazs bamer
# banzer roland | roland banzer
# hugo barbossa | hugo barbosa
# eric barenzung | eric baerenzung
# barmettler marc | marc barmettler
# patric b | patric bartl
# baertschi christian | christian baertschi
# h basyildiz | hueseyin basyildiz
# stefan bauder | stefan bauder
# roger baumer | roger jean max baumer brunner
# hp baumgartner | hanspeter baumgartner
# kevin baumgartner | kevin baumgartner
# sebi baumgartner | sebastian baumgartner
# ch bellue | chantal bellue
# annina s benz | annina benz
# martin l berg | martin berg
# bella berger | isabelle berger
# ilir a berisha | ilir berisha
# martin bernasconi | martin bernasconi
# sandrober | sandro berta
# jasmin bertschinger | jasmin bertschinger
# betschart ruedi | ruedi betschart
# robi beyeler | robert beyeler
# iveta maria bicker | iveta maria bicker
# steebieri | stefan bieri
# chbirmele | christian birmele
# bischofpatrick | patrick bischof
# m i bischofberger | ivo bischofberger
# martin bislin | martin bislin
# bissetatjana | tatjana bisse
# blanchard marc | marc blanchard
# blaser kurt | kurt blaser
# nicole bla | nicole blaser
# robert blaser | robert blaser
# rolf blattmann | rolf blattmann
# ruedi blattmann | ruedi f  blattmann
# tillmann i | tillmann blauss
# maic bless | marc bless
# andibloch | andreas bloch
# benjamin blum | ben blum
# alex bogorin | alexandru bogorin
# andybohnenblust | andreas bohnenblust
# marco bolli | marco bolli
# heinz bollinger | heinz c  bollinger
# pietro brossi | pietro bossi
# oliver bouvard | oliver bouvard
# thomas boxler | thomas boxler
# pascal brand | pascal brand
# philippe brandes | philippe brandes
# peter brandli | peter braendli
# brandstetter corinne | corinne brandstetter
# reto brechbuehl | reto brechbuehl
# rebeccabrechbuhl | rebecca brechbuehl
# robert briner | robert g  briner
# rogerbritschgi ch | roger britschgi
# r s brooks | roger brooks
# roger bruhin | roger bruhin
# barbarabb | barbara brunner
# patrick brunner  | patrick brunner
# marcel br | marcel brunschwiler
# erich bucher | erich bucher
# bucher mark | mark bucher
# stefan buechi ch | stefan buechi
# buchsklaus | klaus buchs
# kebuck | kevin buck
# marco m buechel | marco buechel
# cedric rene buehler | cedric buehler
# hp buehler | hanspeter buehler
# ch buehlmann | christoph buehlmann
# iris buehlmann | iris buehlmann
# da buhre | daniel buhre
# andybulich | andreas bulich
# toni bunter | toni buenter
# anita burch | anita burch
# ch burckhardt | christoph burckhardt
# stefan a buergi | stefan buergi
# burkhalterj | juerg burkhalter
# nicolec buerki | nicole buerki
# burri andreas | andreas burri
# chr calabro | christian calabro
# marco campanella | marco claudio campanella
# marina carobbio | marina carrobio
# chappuis pierre | pierre chappuis
# roland chiap | roland chiap
# christen peter | peter christen
# stefan christae | stefan christen
# christoph dalcher | christoph christoph dalcher
# christopher jost | christopher christopher jost
# alex clapper | alex clapper
# claudio berther | claudio claudio berther
# vcolicchio | vito colichio
# constanze kolbe | constanze constanze kolbe
# aline curty piva | aline curty
# marco dalessandro | marco d alessandro
# karin damico | karin d amico
# severin dheureuse | severin d heureuse
# rainer dacruz | rainer da cruz
# rui dasilva | rui da silva
# daniel stoeckli | stoeckli daniel
# ocdaeniker | oliver daeniker
# nhatha dao | nhat ha dao
# darwiche karim | karim darwiche
# carmen delacruz | carmen de la cruz
# reto demartin | reto de martin
# thomas baumann | thomas de oliveira baumann
# lucien derooij | lucien de rooij
# alex de zeeuw | alex b  de zeeuw
# matdeibel | matthias deibel
# p del conte | patrick del conte
# roberto delsiena | roberto del siena
# martin dellavecchia | martin della vecchia
# carlo a deme | carlo a  deme
# denus robert | robert denuss
# ch denzler | christian denzler
# gisela deyle | gisela deyle ruppe
# rdiebenedetto | roberto di benedetto
# diiorioaldo | aldo di iorio
# dias celine | celine dias
# vdoelger | veronique doelger
# severin d | severin dommen
# domont guillaume | guillaume domont
# denniz donmez | denniz doenmez
# reda dz | reda du
# durand martin | martin durand
# duerstaaron | aaron duerst
# dutler david | david dutler
# roger eberle | roger eberle
# malin ekdahl | malin eckdahl
# andrea alberto egger | andrea alberto egger
# aoeggimann | andreas eggimann
# s egli | stefan egli
# g ehrler | guido ehrler
# fam eichmueller | willi eichmueller
# peter elbenna | peter el benna
# immerelizabeth | elizabeth elizabeth immer
# omnia s elsaadany | omnia elsaadany
# emilio alvarez | emilio elvarez
# premmenegger | paul emmenegger
# rogemmenegger | roger emmenegger
# dominic endrizzi | domic endrizzi
# ch enggist | christoph enggist
# engler pascal | pascal engler
# alex ernst | alexander ernst
# andreas p ernst | andreas ernst
# valescudero | valeria escudero
# beat etter | beat etter
# fabienne kursfeld | fabienne fabienne kursfeld
# martin fasel | martin fasel
# sophie fauser | sophie fauser
# fabio federici | fabio federici
# hans fehr | hans fehr
# rudolf felder | ruedi felder
# simon fellermeyer | simon fellermeyer
# sascha | sascha feucht
# feuz hanspeter | hanspeter feuz
# adfichter | adrienne fichter
# fingerroman | roman finger
# fredy fischer | alfred fischer
# chrigu fischer | christian fischer
# heiko fischer | heiko fischer
# jerome fischer  | jerome fischer
# jfjoel fischer | joel fischer
# markus fischer | markus fischer
# georges fleuti | georges fleuti bardet
# maflierl | matthias flierl
# manfred flueck | manfred f  flueck
# fly fontana | flavio fontana
# frankbarner | frank frank barner
# frank eiselt | frank frank eiselt
# simone fr | simone frattini
# josef frei | josef h  frei
# patrick frei | patrick frei
# markus j freuler | markus freuler
# samuel a fricker | samuel fricker
# fuchs adrian | adrian fuchs
# steffuchs | stefan fuchs
# mathias fuchs | mathias fuchst
# thfueeg | theo fueeg
# roman fueglist | roman fueglister
# thomas fuhrer | thomas fuhrer
# cornelia furrer | cornelia furrer
# dr paulo galhano | paulo galhano
# asim ganic | asim ganic
# serge garazi | serge garazi ict
# markus p gasser | markus gasser
# gataric sasa | sasa gataric
# gebran rawan | rawan gebren
# geetanjali bhat | geetanjali geetanjali shanker bhat
# marc gehling | m  gehling
# matth geiger | matthias geiger
# marie jose genolet | marie genolet
# flgeorg | florian georg
# th gerber | thomas gerber
# ulrich gerber godyn | ulrich gerber
# jrgermanier | jean rene germanier
# setareh gharibi | setareh gharibi
# cp gilbert | catherine gilbert
# j vital girod | jean vitae girod
# adrian gisler | adrian gisler walker
# glaser tobias | tobias glaser
# paulfranz glutz | paul glutz
# johannes | johannes gnaegi
# andreas goeldi | andreas goeldi
# bea gonzalez | beatriz gonzalez
# j gonzalez garcia | javier gonzalez garcia
# pablo gonzalez linares | pablo gonzalez linares
# jarek gorecki | jaroslaw gorecki
# matthias graf for president | matthias graf
# paulgraf | paul andre graf
# grec horiana | horiana grec
# dominique gressly | dominique gressly
# roman gribi | roman gribi
# grieder ursula | ursula grieder
# grosch laios | laios grosch
# jobs grossmann | thomas grossmann
# mgruebler | michael grueebler
# urs gruebler | urs grueebler
# urs gruetter | urs gruetter
# guebeli franz | franz guebeli
# kathrin gubler | katharina gubler
# ufuk guergen | ufuk guergen
# guggisberg marco | marco guggisberg
# alicem gueler | ali cem gueler
# guenter simon | simon guenter
# john guthoerl | john martin guthoerl
# furkanguvenc | furkan guevenc
# ulrich gysel | ulrich emanuel gysel
# gysler stephanie | stephanie gysler
# urs haag | urs haag
# sandro haas lu | sandro haas
# brigitte haeberli | brigitte haeberli koller
# cornelia haebich | cornelia haebich
# christian rudolf habluetzel | christian habluetzel
# th halbeisen | thomas halbeisen
# xavier hall | francis xavier hall
# r haltinner | roman haltinner
# haemmerli simon | simon haemmerli
# hans rosenberger | hans hans rosenberger
# sandy haerdi | sandra haerdi
# hartmann eugen | eugen hartmann
# fabian hartmann | fabian hartmann
# hartmann melanie | melanie hartmann
# hj hassler | hansjoerg hassler
# adi hatzi | adrian hatzi
# timon d hauber | timon hauber
# dani hauenstein | daniel hauenstein
# christian hauser | christian hauser
# ch hediger | christa hediger
# luca heger | luca heger
# luzihehr | luzian hehr
# chrigu heim | christian heim
# sandra barbara heiniger | sandra heiniger
# h j heinimann | hans joerg heinimann
# hellerbruno | bruno heller
# mar hengartner | martin hengartner
# jhennekeuser | johannes hennekeuser
# juanan hernandez | juan antonio hernandez
# marcherrmann | markus herrmann
# rene a herrmann | rene herrmann
# herzogstephanie | stephanie herzog
# hessmanuel | manuel hess
# roger hess | roger hess
# heuberger pius | pius heuberger
# a s hintermann | allen hintermann
# hintermann max | max hintermann
# hirsbrunner david | david hirsbrunner
# chrishoechli | christoph hoechli
# raphael hodel | raphael hodel
# br hofer | bruno hofer
# hansjuerg hofer | hans juerg hofer
# kath hofer | katharina hofer
# phhofer | philipp hofer
# hoffmann tho | thomas hoffmann
# mh martin hoffmann | martin hoffmenn
# stefan hofmann | stefan hofmann
# hofmannluecke | gabriele hofmann luecke
# g homberger | gabriela homberger
# markus horn | markus stefan horn
# franzludwig horner | franz ludwig horner
# manuel theodor huber | manuel huber
# math huber | mathias huber
# jolanda hug | jolanda hug
# helmut hummel | helmut l  hummel
# thomas huerlimann | thomas huerlimann
# inorba huerzeler | heinz huerzeler
# huesemann stefan | stefan huesemann
# dani huser | daniel huser
# benjamin huelsen | benjamin hueslen
# drhuesler | daniel huesler
# chyvert | christiane hyvert
# linaibnidriss | lina ibnidris
# pietro imhof | pietro g  imhof
# imhof simone | simone imhof
# beat ineichen | beat ineichen
# patricia hediger | patricia jaccaud hediger
# nadineninette jaeger | nadine jaeger
# dejanosevic | dejan janosevic
# jeanette mittendrein | jeanette jeanette mittendrein
# miguel jimenez | miguel angel jimenez
# joachim gaisser | gaisser joachim
# rmf luethi | rudolf luethi
# maack michael | michael maack
# maca ranucci | macarena macarena ranucci
# peter k maeder | peter maeder
# maier moritz | moritz maier
# danymaillardb | dany maillard
# thmaissen | theo maissen
# lxmaldonado | alex maldonado
# marcel baumann | baumann marcel
# marco tommasone | marco marco tommasone
# andreadario markotic | andrea dario markotic
# silvano marsano | silvano marsano
# martinbaeriswyl | baeriswyl martin
# martin ruderisch | martin martin ruderisch
# marxer max | maximilian marxer
# mario maslic | mario ventura maslic
# mastro | mattia mastropietro
# uli mauch sis | uli mauch
# christoph maurer | christoph maurer
# sm maurer | simon maurer
# maxim mayorov | max mayorov
# roxana medinaceli | roxana medinaceli
# leonardo mei | leonardo mei
# andre meier | andre meier
# christoph meier | christoph meier
# hanspeter meier junior | hanspeter meier
# herbmeier | herbert meier
# mail markus meier | markus meier
# marlene meier | marlen meier
# sam d meier | samuel meier
# sandra n meier | sandra n  meier
# ernst meihau | ernst meier hausherr
# man meisel | manuel meisel
# stephan meister | stephan w  meister
# merzlikin zoran | zoran merzlikin
# simonmarc messerli | simon messerli
# yorik metzger | yorik metger
# meyer claude | claude meyer
# michael meyer | michael meyer
# meyer pascal | pascal meyer
# sascha m meyer | sascha meyer
# stefan meyer | stefan meyer
# michelbucher | bucher michel
# roli michel | roland michel
# michel ruhle | ruhle michel
# michelle wirth | michelle michelle wirth
# pauljmilner | paul milner
# andy minnig | andreas minnig
# mirko carlesso | mirko mirko carlesso
# alex moeri | alexandre moeri
# gumoeller | gudrun moeller
# l moeller | lukas moeller
# leoniemollet | leonie s  mollet
# friedrich nishio | monika monika friedrich nishio
# martin m moor | martin moor
# g morina | granit morina
# fa mueller | fabian mueller
# janice mueller | janice mueller
# andreasj mueller | andreas mueller
# christoph mueller  | christoph mueller
# mueller dominic | dominic mueller
# kudimueller | kurt mueller
# lukasnmueller | lukas mueller
# markus mueller ch | markus mueller
# mathias p mueller | mathias mueller
# muellermeinhard | meinhard mueller
# pat mueller | patrick mueller
# ralphericmueller | ralph eric mueller
# mueller raoul | raoul mueller
# rh mueller | roger mueller
# ro mueller | rolf mueller
# sabine mueller ledermann | sabine mueller
# susanne leslie mueller | susanne mueller
# swen mueller | swen mueller
# tanja muller | tanja mueller
# urs b mueller | urs mueller
# wo mueller | walter mueller
# muenchbach cathrin | cathrin muenchbach
# momuenger | monika muenger
# pamuenger | patrick muenger
# munzingersimon | simon munzinger
# chris mutter | christof mutter
# philipp nadig | philipp nadig
# ha nagel | hans nagel
# edi namar | edi namar
# alejandronrd | alejandro nardo
# and nardone | andrea nardone
# nedzad erdic | erdic nedzad
# neuenschwander sabine | sabine neuenschwander
# rp neumann | raphael neumann
# it news | it news
# ja nguy | jason nguy
# dat ng | dat nguyen
# niederhaeuser peter | peter niederhaeuser
# daniel notter | daniel notter egli
# nicolas novak  | nicolas novak
# peter a nussbaumer | peter a  nussbaumer
# christian ochsner | chrisitan ochsner
# sa ochsner | samuel ochsner
# leoertle | levin oertle
# regula oettli | regula oettli leutwyler
# stephan osterwald | stephan osterwald
# markus ott | markus m  ott
# canozarna | can oezarna
# labinot pajaziti | labinot pajaziti
# pamukarzu | arzu pamuk
# eva parth | eva parth
# pasini florian | florian pasini
# pasinipiero | piero pasini
# pasquier jacqueline | jacqueline pasquier
# pauli amelie | amelie pauli
# christine pellet | christine pellet
# guenter penzenauer | guenter penzenauer
# persi marco | marco persi
# peter andres | andres peter
# benjamin peter | benjamin peter
# peter kiowski | peter peter kiowski
# michi peterhans | michael peterhans
# petrinobruno | bruno petrino
# stjepan petrovic | stjepan petrovic
# cpfenninger | christian pfenninger
# andrea pfister | andrea pfister
# pa pfister | patrick pfister
# rene pfister | rene pfister
# sarah piller | sarah piller
# max pineda | max h  pineda
# m plaschy | martin plaschy
# pospisil lukas | lukas pospisil
# tanja preissinger | tanja preissinger
# priska fuchs | priska priska fuchs
# maprizio | maurizio prizio
# probst jonas | jonas probst
# nicolas livius probst | nicolas probst
# christiano puglia | christiano puglia
# ecaterina puricel | ecaterina puricel
# b puerro | bettina puerro
# charles raas | charles raas
# rahner andreas | andreas rahner
# alex ramm | alexander ramm
# rathgebmichael | michael rathgeb
# reber daniel | daniel reber
# marcelr | marcel reber
# greg rechsteiner | gregor rechsteiner
# comelli renato | renato renato comelli
# ninarentschler | nina lulu rentschler
# reto wagner ch | reto reto wagner
# em reznik | emilia reznik
# seb rickman | sebastian rickmann
# riedel phillip | phillip riedel
# hansjoerg riepl | hansjoerg riepl
# manuel ringger | manuel ringger
# philipp riniker | philipp georg riniker
# christian ritter | christian ritter
# marcrodriguezsanz | marc rodriguez sanz
# priska roelli | priska roelli
# markus roggli | markus roggli
# matthias | matthias roehn
# lukas rohner | lukas rohner
# benno roelli | benno roelli
# roellin jasmin | jasmin roellin
# roman zuerrer | roman roman zuerrer
# nicolas roeschli | nicolas jannik roeschli
# peter rosenberg | peter rosenberg
# celincarmen roth | celina roth
# felix roth | felix roth
# raph roth | raphael roth
# ursdroth | urs roth
# h r rothenbuehler | hans rudolf rothenbuehler
# hubert roetzer | hubert josef roetzer
# viruch | victor ruch
# stefanrudolf | stefan f  rudolf
# micolas rudyk | mykola rudyk
# dani rueegg | daniel rueegg
# mar rueegg | marcel rueegg
# michael zaugg | michael rueegg
# balzruegger | balz rueegger
# rueegger david | david rueegger
# ch ruefenacht | christoph ruefenacht
# st rufinatscha | stefanie rufinatscha
# bianca ruehle heeb | bianca ruehle
# m rusch | markus rusch
# pat rusconi | patrizio rusconi
# urrust | urs rust
# marcel rutz | marcel rutz
# rutz roger | roger rutz
# susi rutz | susi rutz
# marina ruzio | marina ruzio
# sabine jaag | sabine sabine jaag
# salzmann rolf | rolf salzmann
# ivana samarova | ivana samarova
# marcel samstag | marcel m samstag
# ainelsanchez | ainel sanchez gonzalez
# catherine sander | catherine sander
# nathsander | nathan sander
# juanluis sanz | juan luis sanz
# sarpong george | george sarpong
# ursula schacher | ursula schacher
# markus schaden | markus schaden
# stefan schaerli | stefan schaerli
# davidschaeferch | david schaefer
# schafer xaver | xaver schafer
# dany schaffner | daniel schaffner
# schibli ernst | ernst schibli
# martin schick | martin schick pauli
# th schlaepfer | thomas schlaepfer
# joerg schlater | joerg schlatter
# rita m schleiss | rita schleiss
# adischmid | adrian schmid
# schmid ralph d | ralph david schmid
# rolfhschmid | rolf h  schmid
# ruschmid | rudolf schmid
# bastian schmidmeister | bastian schmidmeister
# t schmidt | thomas schmidt
# silvia schmidt | silvia schmidt keller
# daniel schmutz | daniel schmutz
# schneeberger ph | philipp schneeberger
# philippe schneider | philippe schneider
# reto schneider | reto schneider
# schneider stephan  | stephan schneider
# raymond schnidrig | raymond schnidrig
# sandra j schnyder | sandra schnyder
# d schreier | daniela schreier
# weschreijer | wolfgang schreijer
# schroedergunnar | gunnar schroeder
# phil schroeder | philipp schroeder
# richard schubnell | richard f  schubnell
# heinz schuetz | heinz peter schuetz
# beni schuler | bernhard schuler
# schumacher esth | esther schumacher
# sven schumacher | sven schumacher
# th schumacher | thomas schumacher
# s schumpeter | sascha schumpeter
# schuepbachmanuel | manuel schuepbach
# heinz schuetz | heinz peter schuetz
# alschwab | alain schwab
# michi schwab | michael schwab
# pat schwab | patrick schwab
# schwarz dominik | dominik schwarz
# dany schweizer | daniel schweizer
# j p schweizer | jan schweizer
# tinu schweizer | martin schweizer
# m schweizer | matthias schweizer
# bahner sebastian | sebastian sebastian bahner
# roger seiler ch | roger seiler
# sebastian seiler zh | sebastian seiler
# jodok senften | jodok senften
# chrigi senn | christoph senn
# marlies senn | marlies senn kaufmann
# seraina dosch | seraina seraina dosch
# serge baumberger | serge serge wolf
# pashkov s | pashkov siarhei
# sidlermarcel | marcel sidler
# siegmann jelena | jelena siegmann
# daniel sigrist | daniel sigrist
# rm sigrist | roger sigrist
# taija sigrist | taija sigrist
# mr adriansimon | adrian simon
# role simon | roland simon
# soland silvia | silvia soland
# sabine sollberger | sabine sollberger solari
# martin som | martin som
# sommer andre | andre sommer
# martin somm | martin sommer
# sopran patrik | patrik sopran
# andreas springer | andreas springer
# sam spycher | samuel spycher
# thorsten staby | thorsten staby
# wa stadelmann | walter stadelmann
# stadler hansruedi | handruedi stadler
# renato stadler | renato stadler
# staeger kevin | kevin staeger
# nikola stankovic  | nikola stankovic
# dominic starkl | dominic starkl
# dominik st | dominik staeuble
# digusteffen | dieter steffen
# steinbach markus | markus steinbach
# andresonjasteiner | andre steiner
# andy steiner | andreas steiner
# ant steiner | antony steiner
# marc steiner | marc steiner
# steiner michael | michael steiner
# steiner rafael | rafael steiner
# sarah steiner | sarah steiner
# hanno steinke | hanno g  steinke
# peterthomas steinmann | peter t  steinmann
# emmeline s | emmeline stempfel
# daniel stocker | daniel stocker
# corinasto | corina stofer
# karamitrovstojan | stojan stojan karamitrov
# stoyan robert | robert stoyan
# matt strebel | matthias strebel
# niki strukov | nikita strukov
# ep stucki | ernst stucki
# erich studer | erich studer
# theo studer | theophile studer
# studermarc | marc studer marc
# stutz martin | martin stutz
# susan schnurrenberger | susan angela susan angela schnurrenberger
# suter robin | robin suter
# mats svensson | mats o  p  svensson
# christian syz | chris syz
# attila szabo | attila szabo
# zsszalay | zsuzsanna szalay
# tanja a berger | tanja tanja berger
# tester adrian  | adrian tester
# thomas ebermann | ebermann thomas
# thomi manfred | manfred thomi
# daniel tobler | daniel tober
# tobias honolka | tobias tobias honolka
# tobler rolf | rolf tobler
# velitopyurek | veli topyuerek
# p tottle | paul tottle
# ch traut | christine traut
# spasen trendafilov | spasen trendafilov
# cyril truninger | cyril jammin truninger
# matschudin | marcel tschudin
# st tschudin | stefan tschudin
# r tschupp | raffael tschupp
# tuhcic nermin | nermin tuhcic
# p tuescher | patrick tuescher
# reni uhlmann | renata uhlmann
# michaelu | michael ullrich
# steven urbach | steven urbach
# vahid moradi ch | moradi vahid
# athi vait | athi vaithilingam
# valentin schmidt | valentin valentin schmidt
# ruben a vallmitjana | ruben vallmitjana
# philip vandenberg | philip e  van den berg
# frans van den brul | frans van den brul
# sietse vanderhaas | sietse van der haas
# han vanderkleij | han van der kleij
# peter vandijke | peter van dijke
# christian vansinger | christian van singer
# anavasilyeva | anastasia vasilyeva
# jaqueline vasquez | jaqueline vasquez velazco
# veizirando | rando veizi
# verzinolaura | laura verzino
# marianne villalaz | mary villalaz
# r b vogelsanger | rebecca vogelsanger
# patrick za vogt | patrick vogt
# martin vogt | wilhelm martin vogt
# bernhard vonallmen | bernhard von allmen
# naomi vonallmen | naomi von allmen
# ulrich vonarx | ulrich von arx
# vonballmoos | rolf von ballmoos
# von barnekow alec | alec von barnekow
# peter von bergen | peter von bergen
# juerg von bueren | juerg von bueren
# vonbueren pascal | pascal von bueren
# babs von euw | barbara von euw
# ruedi von felten | ruedi von felten
# peter vongrebel | peter von grebel
# manfred von gruenigen | manfred von gruenigen
# andreas vongunten | andreas von gunten
# andreas vonkaenel | andreas von kaenel
# christoph von rechenberg | von rechenberg von rechenberg
# christoph vonrotz | christoph von rotz
# mvschulthess | marc von schulthess
# lennart vonthiessen | lennart von thiessen
# vonlanthenthomas | thomas vonlanthen
# patrick c walther | patrick walther
# peter walti | peter r  walti
# waelti simon | simon waelti
# wanner herbert | herbert wanner
# aw waraich | abdul waraich
# heinrich waser | heinrich josef waser
# dani wattenhofer | daniel wattenhofer
# daniel weber  | daniel weber
# weber lars  | lars weber
# roman weber | roman weber
# romeo weber | romeo weber
# tobias weber | tobias weber
# wehrlimartin | martin wehrli
# moritz wehrli | moritz wehrli
# tom wehrli | thomas wehrli
# tom j weishaupt | thomas weishaupt
# pe welti | peter welti
# alwerder | alfred werder
# m wernigg | michael wernigg
# martin c wettstein | martin wettstein
# johannes wetzel | johannes wetzel
# louispaul wicki | louis paul wicki
# melchior wicki | melchior wicki marbacher
# u widmann | uwe widmann
# k widmer | katja widmer
# urshwidmer | urs widmer
# michael wilhelm | michael c  wilhelm
# patrik willi | patrik willi
# dhp winkler | dora winkler
# alexander c wirth | alexander wirth
# robert wirz scf | robert wirz
# wirz thomas | thomas wirz
# sascha wisskirchen | sascha patrik wisskirchen
# thwittek | thomas wittek
# piotrzwojcik | piotr wojcik
# patrice wolf mobil | patrice wolf
# anton wuest | anton wuest
# wuethrich benjamin | benjamin wuethrich
# a wyrsch | adrian wyrsch
# edi wyss | eduard wyss
# stefan wyss | stephan f  wyss
# ursula wyss | ursula wyss
# yannick rennhard | rennhard yannick
# guamar yientut | guamar yien tut
# thomas zrotz | thomas z rotz
# zehnderdominik | dominik zehnder
# zemanmark | mark zeman
# immi zerbini | immanuel zerbini
# ph ziegler | philipp ziegler
# chriszimmermann | christoph zimmermann
# fcazimmermann | frank zimmermann
# martin zimmermann | martin zimmermann
# rolf zimmermann | rolf zimmermann
# julzioerjen | julian zioerjen
# sini zivkovic | sini zivkovic
# zmitrowiczkarolina | karolina zmitrowicz
# floriane zollinger loew | floriane zollinger loew
# julia zon | julia zon
# rzueger | reto zueger
# mazuercher | matthias zuercher
# mike zuercher | michael zuercher
# corinne zwimpfer | corinne zwimpfer
# 17.087421655654907

# %%
df = pd.read_excel("output.xlsx")

simple = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Simple Match"].to_list())
soundex = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Soundex"].to_list())
soundex_custom = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Soundex Custom"].to_list())
koln = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Koln"].to_list())
ls = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Levenshtein"].to_list())
cos = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Ngram Similarity"].to_list())
lsh = measure_metrics2(df["Duplikat mit Id"].to_list(), df["LSH Similarity"].to_list())

simple, soundex, soundex_custom, koln, ls, cos, lsh
# Out:
# ((0.8461538461538461, 0.8153846153846154, 0.8256410256410257),
#  (0.3132352941176471, 0.41911764705882354, 0.3434873949579832),
#  (0.6436781609195402, 0.632183908045977, 0.636015325670498),
#  (0.6867469879518072, 0.6626506024096386, 0.6706827309236948),
#  (0.7733333333333333, 0.76, 0.7644444444444445),
#  (0.8513513513513513, 0.8513513513513513, 0.8513513513513513),
#  (0.8955223880597015, 0.8805970149253731, 0.8855721393034827))

# %%
"""
Rerun all algorithms, if "TypeError: 'tuple' object is not callable" appears

"""


df = pd.read_csv("restaurants.tsv", sep="\t")
import time
print(df)
namen = unidecoded(df["name"]).to_list()

#each algo should get a weight; simple match most weight. Do hyperparameter tuning to find best weightmatrix
df["Standardized"] = str(0)
index = 0
for name in namen:
    df.at[index, "Standardized"] = replace_non_letters(name)

    index += 1
    
simple(df["Standardized"])
soundex(df["Standardized"])
soundex_custom(df["Standardized"])
koln(df, "Standardized")
levenshtein(df["Standardized"])
ngram_similarity(df["Standardized"])
start = time.time()
lsh_similarity_check(df["Standardized"])
end = time.time()

print(end - start)
df.to_excel("output - restaurant.xlsx")
# Out:
#       ID                           name                  address  \
# 0      1      arnie morton's of chicago   435 s. la cienega blv.
# 1      2      arnie morton's of chicago  435 s. la cienega blvd.
# 2      3             art's delicatessen      12224 ventura blvd.
# 3      4                     art's deli      12224 ventura blvd.
# 4      5                  hotel bel-air     701 stone canyon rd.
# ..   ...                            ...                      ...
# 859  860                        ti couz            3108 16th st.
# 860  861                      trio cafe        1870 fillmore st.
# 861  862                         tu lan              8 sixth st.
# 862  863                vicolo pizzeria              201 ivy st.
# 863  864  wa-ha-ka oaxaca mexican grill            2141 polk st.
#
#               city         phone         type Duplikat mit Id
# 0      los angeles  310/246-1501     american            1, 2
# 1      los angeles  310-246-1501  steakhouses            1, 2
# 2      studio city  818/762-1221     american            3, 4
# 3      studio city  818-762-1221        delis            3, 4
# 4          bel air  310/472-1211  californian            5, 6
# ..             ...           ...          ...             ...
# 859  san francisco  415-252-7373       french             860
# 860  san francisco  415-563-2248     american             861
# 861  san francisco  415-626-0927   vietnamese             862
# 862  san francisco  415-863-2382        pizza             863
# 863  san francisco  415-775-1055      mexican             864
#
# [864 rows x 7 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 20
#      16     df.at[index, "Standardized"] = replace_non_letters(name)
#      18     index += 1
# ---> 20 simple(df["Standardized"])
#      21 soundex(df["Standardized"])
#      22 soundex_custom(df["Standardized"])
#
# TypeError: 'tuple' object is not callable

# %%
df = pd.read_excel("output - restaurant.xlsx")

simple = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Simple Match"].to_list(), include_non_dups=True)
soundex = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Soundex"].to_list(), include_non_dups=True)
soundex_custom = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Soundex Custom"].to_list(), include_non_dups=True)
koln = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Koln"].to_list(), include_non_dups=True)
ls = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Levenshtein"].to_list(), include_non_dups=True)
cos = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Ngram Similarity"].to_list(), include_non_dups=True)
ngram = measure_metrics2(df["Duplikat mit Id"].to_list(), df["LSH Similarity"].to_list(), include_non_dups=True)

simple, soundex, soundex_custom, koln, ls, cos, ngram
# Out:
# ((0.9166666666666666, 0.9166666666666666, 0.9166666666666666),
#  (0.6172288359788359, 0.6597222222222222, 0.6294367283950616),
#  (0.8993055555555556, 0.9004629629629629, 0.8996913580246912),
#  (0.8692129629629629, 0.8715277777777778, 0.8699845679012347),
#  (0.8416923868312757, 0.8495370370370371, 0.8433311287477955),
#  (0.8923611111111112, 0.8958333333333334, 0.8935185185185185),
#  (0.9166666666666666, 0.9178240740740741, 0.9170524691358024))

# %%
"""
Rerun all algorithms, if "TypeError: 'tuple' object is not callable" appears

"""

df = pd.read_csv("cora.tsv", sep="\t")
import time

authors = unidecoded(df["authors"]).to_list()
title = unidecoded(df["authors"]).to_list()

df["Standardized"] = str(0)
index = 0
for author, tit in zip(authors, title):
    
    if author == "nan":
        to_check = tit
    
    else:
        to_check = author
    df.at[index, "Standardized"] = to_check
    index += 1
    
simple(df["Standardized"])
soundex(df["Standardized"])
soundex_custom(df["Standardized"])
koln(df, "Standardized")
levenshtein(df["Standardized"])
ngram_similarity(df["Standardized"])
start = time.time()
lsh_similarity_check(df["Standardized"])
end = time.time()

print(end - start)
df.to_excel("output - cora.xlsx")

# %%
df = pd.read_excel("output - cora.xlsx")

simple = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Simple Match"].to_list())
soundex = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Soundex"].to_list())
soundex_custom = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Soundex Custom"].to_list())
koln = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Koln"].to_list())
ls = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Levenshtein"].to_list())
cos = measure_metrics2(df["Duplikat mit Id"].to_list(), df["Ngram Similarity"].to_list())
ngram = measure_metrics2(df["Duplikat mit Id"].to_list(), df["LSH Similarity"].to_list())

simple, soundex, soundex_custom, koln, ls, cos, ngram
